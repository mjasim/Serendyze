# %%
import pandas as pd

# %%
df = pd.read_json("mat_data_cc.json")

df
# Out:
#                                              comments  \
# 0   [{'comment_id': 0, 'comment': 'A structure or ...
# 1   [{'comment_id': 36, 'comment': 'This could be ...
# 2   [{'comment_id': 59, 'comment': 'It's more diff...
# 3   [{'comment_id': 85, 'comment': 'Mobility won't...
# 4   [{'comment_id': 111, 'comment': 'merge art and...
# 5   [{'comment_id': 139, 'comment': 'you'd have a ...
# 6   [{'comment_id': 155, 'comment': 'It would impa...
# 7   [{'comment_id': 175, 'comment': 'The idea to c...
# 8   [{'comment_id': 200, 'comment': 'In this way t...
# 9   [{'comment_id': 234, 'comment': 'What will the...
# 10  [{'comment_id': 235, 'comment': 'I love it', '...
# 11  [{'comment_id': 256, 'comment': 'Completely fe...
# 12  [{'comment_id': 277, 'comment': 'Sense of plac...
# 13  [{'comment_id': 284, 'comment': 'Without more ...
# 14  [{'comment_id': 303, 'comment': 'Exactly!  Spe...
# 15  [{'comment_id': 309, 'comment': 'I don't have ...
# ...

# %%
proposal = input()

prop_data = df.loc[df["discussion_name"] == proposal]
topics = prop_data["topics"].tolist()
# Out:
# Interactive Art

# %%
for t in topics:
    for i in t:
        print(i["topic_phrase"])
# Out:
# most public art
# homeless people
# local artists
# increase pedestrian traffic
